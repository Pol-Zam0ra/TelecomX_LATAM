# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %% [markdown]
# #**Conoce el conjunto de datos**

# %%
df = pd.read_json('/content/TelecomX_Data.json')
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# ##**Comprobación de incoherencias en los datos**

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
df.isnull().any(axis=1).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##**Manejo de inconsistencias**

# %%
df['Churn'] = df['Churn'].str.strip().str.lower().replace('', 'yes')
df['Churn'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    no  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    no  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df['customer_gender'] = df['customer'].apply(lambda x: x['gender'].strip().capitalize())
df['customer_gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['customer_senior'] = df['customer'].apply(lambda x: int(x['SeniorCitizen']))
df['customer_senior'].value_counts()
# Out:
# customer_senior
# 0    6085
# 1    1182
# Name: count, dtype: int64

# %%
df['charges_monthly'] = df['account'].apply(lambda x: x['Charges']['Monthly'] if 'Charges' in x and 'Monthly' in x['Charges'] else None)
df['charges_monthly'] = pd.to_numeric(df['charges_monthly'], errors='coerce')
df['charges_monthly'].head()
# Out:
# 0    65.6
# 1    59.9
# 2    73.9
# 3    98.0
# 4    83.9
# Name: charges_monthly, dtype: float64

# %%
df['charges_total'] = df['account'].apply(lambda x: x['Charges']['Total'] if 'Charges' in x and 'Total' in x['Charges'] else None)
df['charges_total'] = pd.to_numeric(df['charges_total'], errors='coerce')
df['charges_total'].head()
# Out:
# 0     593.30
# 1     542.40
# 2     280.85
# 3    1237.85
# 4     267.40
# Name: charges_total, dtype: float64

# %%
df['contract'] = df['account'].apply(lambda x: x.get('Contract', None))
df['contract'].head()
# Out:
# 0          One year
# 1    Month-to-month
# 2    Month-to-month
# 3    Month-to-month
# 4    Month-to-month
# Name: contract, dtype: object

# %%
df['contract'] = df['contract'].str.strip().str.lower()

# %%
df['payment_method'] = df['account'].apply(lambda x: x.get('PaymentMethod', None))
df['payment_method'].head()
# Out:
# 0        Mailed check
# 1        Mailed check
# 2    Electronic check
# 3    Electronic check
# 4        Mailed check
# Name: payment_method, dtype: object

# %%
df['internet_service'] = df['internet'].apply(lambda x: x.get('InternetService', None))
df['internet_service'].head()
# Out:
# 0            DSL
# 1            DSL
# 2    Fiber optic
# 3    Fiber optic
# 4    Fiber optic
# Name: internet_service, dtype: object

# %%
df['tech_support'] = df['internet'].apply(lambda x: x.get('TechSupport', None))
df['tech_support'].head()
# Out:
# 0    Yes
# 1     No
# 2     No
# 3     No
# 4    Yes
# Name: tech_support, dtype: object

# %%
df.groupby('contract')['Churn'].value_counts()
# Out:
# contract        Churn
# month-to-month  no       2220
#                 yes      1785
# one year        no       1307
#                 yes       212
# two year        no       1647
#                 yes        96
# Name: count, dtype: int64

# %%
for col in ['contract', 'payment_method', 'internet_service', 'tech_support']:
    df[col] = df[col].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)

df[['contract', 'payment_method', 'internet_service', 'tech_support']].head()
# Out:
#        contract    payment_method internet_service tech_support
# 0      one year      mailed check              dsl          yes
# 1  monthtomonth      mailed check              dsl           no
# 2  monthtomonth  electronic check      fiber optic           no
# 3  monthtomonth  electronic check      fiber optic           no
# 4  monthtomonth      mailed check      fiber optic          yes

# %% [markdown]
# ##**(Opcional) Eliminar las columnas que no se ocuparan**

# %%
#df = df.drop(columns=['customer', 'phone', 'internet', 'account'])
#df.head()

# %%
df.to_json('df_telecom_clean.json', orient='records', indent=2)

# %% [markdown]
# ##**Creando la tabla cuentas diarias**

# %%
df['daily_accounts'] = df['charges_monthly'] / 30
df['daily_accounts'].head()
# Out:
# 0    2.186667
# 1    1.996667
# 2    2.463333
# 3    3.266667
# 4    2.796667
# Name: daily_accounts, dtype: float64

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    no  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    no  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ##**(Opcional) Transformando columnas a binarias**

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'Churn',
#  'customer',
#  'phone',
#  'internet',
#  'account',
#  'customer_gender',
#  'customer_senior',
#  'charges_monthly',
#  'charges_total',
#  'contract',
#  'payment_method',
#  'internet_service',
#  'tech_support',
#  'daily_accounts']

# %%
df['Churn'] = df['Churn'].map({'yes': 1, 'no': 0})
df['tech_support'] = df['tech_support'].map({'yes': 1, 'no': 0})
df[['Churn', 'tech_support']].head()
# Out:
#    Churn  tech_support
# 0      0           1.0
# 1      0           0.0
# 2      1           0.0
# 3      1           0.0
# 4      1           1.0

# %%
df['tech_support'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: tech_support
# Non-Null Count  Dtype
# --------------  -----
# 5686 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
df['tech_support'] = df['tech_support'].fillna(0)
df['tech_support'] = df['tech_support'].astype(int)

# %%
df[['Churn', 'tech_support']].head()
# Out:
#    Churn  tech_support
# 0      0             1
# 1      0             0
# 2      1             0
# 3      1             0
# 4      1             1

# %% [markdown]
# #📊 Carga y análisis

# %%
df.describe()
# Out:
#              Churn  customer_senior  charges_monthly  charges_total  \
# count  7267.000000      7267.000000      7267.000000    7256.000000
# mean      0.288014         0.162653        64.720098    2280.634213
# std       0.452869         0.369074        30.129572    2268.632997
# min       0.000000         0.000000        18.250000      18.800000
# 25%       0.000000         0.000000        35.425000     400.225000
# 50%       0.000000         0.000000        70.300000    1391.000000
# 75%       1.000000         0.000000        89.875000    3785.300000
# max       1.000000         1.000000       118.750000    8684.800000
#
#        tech_support  daily_accounts
# count   7267.000000     7267.000000
# mean       0.289528        2.157337
# std        0.453575        1.004319
# min        0.000000        0.608333
# 25%        0.000000        1.180833
# 50%        0.000000        2.343333
# 75%        1.000000        2.995833
# max        1.000000        3.958333

# %%
df[['charges_monthly', 'charges_total', 'daily_accounts']].describe()
# Out:
#        charges_monthly  charges_total  daily_accounts
# count      7267.000000    7256.000000     7267.000000
# mean         64.720098    2280.634213        2.157337
# std          30.129572    2268.632997        1.004319
# min          18.250000      18.800000        0.608333
# 25%          35.425000     400.225000        1.180833
# 50%          70.300000    1391.000000        2.343333
# 75%          89.875000    3785.300000        2.995833
# max         118.750000    8684.800000        3.958333

# %% [markdown]
# ##**Distribución de evasión (Churn)**

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    5174
# 1    2093
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Churn', palette=['#00B5AD', '#F2711C'])
plt.title('Distribución de Evasión de Clientes', fontsize=16, fontweight='bold')
plt.xlabel('Churn (0 = No, 1 = Sí)', fontsize=13)
plt.ylabel('Cantidad de Clientes', fontsize=13)
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-52-2061686765.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Churn', palette=['#00B5AD', '#F2711C'])

# %% [markdown]
# ##**Recuento de evasión por variables categóricas**

# %%
def GraficarChurnPorCategoria(columna):
    nombresColumnas = {
        'customer_gender': 'Género del Cliente',
        'customer_senior': 'Adulto Mayor',
        'contract': 'Tipo de Contrato',
        'payment_method': 'Método de Pago',
        'internet_service': 'Servicio de Internet',
        'tech_support': 'Soporte Técnico'
    }

    titulo = f'Evasión de Clientes según {nombresColumnas.get(columna, columna)}'

    plt.figure(figsize=(7, 5))
    sns.countplot(data=df, x=columna, hue='Churn', palette='Set2')
    plt.title(titulo, fontsize=15, fontweight='bold')
    plt.xlabel(nombresColumnas.get(columna, columna), fontsize=12)
    plt.ylabel('Cantidad', fontsize=12)
    plt.xticks(rotation=20)
    plt.legend(title='Churn', loc='upper right')
    sns.despine(top=True, right=True)
    plt.tight_layout()
    plt.show()

# %%
GraficarChurnPorCategoria('customer_gender')

# %%
GraficarChurnPorCategoria('contract')

# %%
GraficarChurnPorCategoria('payment_method')

# %%
GraficarChurnPorCategoria('internet_service')

# %%
GraficarChurnPorCategoria('tech_support')

# %% [markdown]
# ##**Conteo de evasión por variables numéricas**

# %%
def GraficaChurnVsVariableNumerica(variable):
    nombresColumnas = {
        'charges_monthly': 'Cargos Mensuales',
        'charges_total': 'Cargos Totales',
        'daily_accounts': 'Cuentas Diarias',
        'servicios_activos': 'Servicios Activos',
        'customer_senior': 'Adulto Mayor'
    }

    nombreBonito = nombresColumnas.get(variable, variable)
    titulo = f'{nombreBonito} vs Evasión de Clientes'

    plt.figure(figsize=(7, 5))
    sns.boxplot(data=df, x='Churn', y=variable, palette='coolwarm')
    plt.title(titulo, fontsize=15, fontweight='bold')
    plt.xlabel('Churn (0 = No, 1 = Sí)', fontsize=12)
    plt.ylabel(nombreBonito, fontsize=12)
    sns.despine(top=True, right=True)
    plt.tight_layout()
    plt.show()

# %%
GraficaChurnVsVariableNumerica('charges_total')
# Out:
# /tmp/ipython-input-68-188690329.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Churn', y=variable, palette='coolwarm')

# %%
GraficaChurnVsVariableNumerica('charges_monthly')
# Out:
# /tmp/ipython-input-62-2358732672.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Churn', y=variable, palette='coolwarm')

# %%
GraficaChurnVsVariableNumerica('daily_accounts')
# Out:
# /tmp/ipython-input-62-2358732672.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Churn', y=variable, palette='coolwarm')

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##**1. Introducción**

# %% [markdown]
# Telecom X enfrenta una alta tasa de cancelación de clientes.  Este análisis busca identificar factores que a que los clientes tomen la decicion de cancelar los servicios de Telecom X, mediante la exploración de datos, visualizaciones y tratamiento previo.
# Los resultados ayudarán a proponer estrategias de retención de los clientes.

# %% [markdown]
# ##**2. Limpieza y tratamiento de datos**

# %% [markdown]
# El conjunto de datos original fue proporcionado en formato JSON e incluía información anidada en forma de diccionarios, agrupando atributos en bloques como `customer`, `account`, `internet` y `phone`.
#
# Para facilitar el análisis, se aplicó una transformación que extrajo las variables más relevantes de dichos diccionarios y se integraron al DataFrame principal como columnas planas.
#
# Entre las acciones realizadas:
#
# - Se eliminaron espacios innecesarios con `.str.strip()` y se estandarizó el texto en minúsculas con `.str.lower()` para unificar categorías.
# - Se crearon nuevas columnas como:
#   - `charges_monthly` y `charges_total` (facturación mensual y total).
#   - `daily_accounts`, calculada dividiendo la facturación mensual entre 30 días.
#   - `customer_senior`, transformando el valor original en un campo numérico para adultos mayores.
# - Se convirtieron valores binarios como `"yes"` y `"no"` en `1` y `0` para facilitar el análisis.
#
# Este proceso aseguró que los datos estuvieran limpios, consistentes y listos para su exploración analítica.

# %% [markdown]
# ##**3. Análisis Exploratorio de Datos**

# %% [markdown]
# Se realizó un análisis exploratorio para identificar patrones relevantes en los datos y comprender el perfil de los clientes que abandonan el servicio.
#
# **Estadísticas Generales:**
#
# - Las métricas como media, mediana, y desviación estándar fueron calculadas para variables numéricas como `charges_total`, `charges_monthly` y `cuentas_diarias`.
# - La mayoría de los clientes presentan cargos mensuales regulares, pero existen valores extremos que pueden corresponder a usuarios con paquetes más avanzados.
#
# **Distribución de Evasión:**
#
# - Se visualizó la variable `Churn` mediante un gráfico de barras.
# - Se identificó un porcentaje considerable de clientes que han cancelado el servicio.
#
# **Análisis por Categorías:**
#
# Se analizaron variables categóricas como `contract`, `payment_method`, `internet_service`, `tech_support`, `customer_gender` y `customer_senior`.
#
# - Se observó una mayor tasa de evasión en clientes con contratos mensuales, así como en aquellos sin soporte técnico.
# - El género o la edad avanzada (`customer_senior`) no mostraron diferencias marcadas en la tasa de cancelación.
#
# Este análisis permitió delimitar los grupos con mayor propensión a la evasión y preparó el terreno para comparaciones con variables numéricas.

# %% [markdown]
# ##**4. Conclusiones e Insights**

# %% [markdown]
# A partir del análisis realizado, se pueden destacar los siguientes hallazgos:
#
# - **Contrato mensual**: Los clientes con este tipo de contrato tienen una probabilidad significativamente mayor de abandonar el servicio.
# - **Facturación baja**: Los usuarios con cargos mensuales y diarios más bajos mostraron una mayor tendencia a cancelar.
# - **Ausencia de soporte técnico**: Aquellos clientes que no tienen acceso a soporte técnico presentan tasas más altas de evasión, lo cual destaca la importancia de este servicio.
# - **Método de pago electrónico**: Algunos métodos, como la facturación electrónica sin soporte humano, podrían correlacionarse con una experiencia de cliente menos satisfactoria.

# %% [markdown]
# ##**5. Recomendaciones**

# %% [markdown]
# - Incentivar a los clientes a adoptar contratos a largo plazo.
# - Mejorar la oferta de soporte técnico.
# - Analizar los segmentos con gastos bajos para entender sus necesidades.

# %%
df.to_json('telecom_final_limpio.json', orient='records', indent=2)

# %% [markdown]
# #¡EXTRA!

# %%
df['servicios_activos'] = df[['tech_support']].sum(axis=1)
df['servicios_activos'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: servicios_activos, dtype: int64

# %%
df[['Churn', 'charges_monthly', 'charges_total', 'customer_senior', 'tech_support', 'daily_accounts', 'servicios_activos']].corr()
# Out:
#                       Churn  charges_monthly  charges_total  customer_senior  \
# Churn              1.000000         0.180306      -0.190198         0.144564
# charges_monthly    0.180306         1.000000       0.652109         0.220388
# charges_total     -0.190198         0.652109       1.000000         0.103499
# customer_senior    0.144564         0.220388       0.103499         1.000000
# tech_support      -0.158111         0.338429       0.431987        -0.059376
# daily_accounts     0.180306         1.000000       0.652109         0.220388
# servicios_activos -0.158111         0.338429       0.431987        -0.059376
#
#                    tech_support  daily_accounts  servicios_activos
# Churn                 -0.158111        0.180306          -0.158111
# charges_monthly        0.338429        1.000000           0.338429
# charges_total          0.431987        0.652109           0.431987
# customer_senior       -0.059376        0.220388          -0.059376
# ...

# %%
sns.heatmap(df[['Churn', 'charges_monthly', 'charges_total', 'customer_senior', 'tech_support', 'daily_accounts', 'servicios_activos']].corr(),
            annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()
